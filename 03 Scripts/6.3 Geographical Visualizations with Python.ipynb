# %% [markdown]
# # Importing Libraries and Data

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\simpe\anaconda3\envs\geo_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import folium
import json

# %%
# %matplotlib inline

# %%
#import US JSON
country_geo= r'C:/Users/simpe/Achievement 6 practice/Data/us-states.json'

# %%
#city JSON
city_geo= r'/Users/simpe/Achievement 6 practice/Data/NYC.geojson'

# %%
city_geo_2 = r'/Users/simpe/Achievement 6 practice/Data/nyc-zip-code-tabulation-areas-polygons.geojson'

# %%
country_geo
# Out:
# 'C:/Users/simpe/Achievement 6 practice/Data/us-states.json'

# %%
city_geo
# Out:
# '/Users/simpe/Achievement 6 practice/Data/NYC.geojson'

# %%
#import csv
#folder shortcut
path = r'/Users/simpe/Citi Bike Analysis'

# %%
citi = pd.read_csv(os.path.join(path, '02 Data','prepared data', 'citi_4.csv'), index_col = False)

# %%
citi.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 day_of_week  start_hour  \
# 0             0             0           0         Mon          18
# 1             1             1           1         Thu          18
# 2             2             2           2         Wed          19
# 3             3             3           3         Sat          11
# 4             4             4           4         Fri          22
#
#    start_station_id       start_station_name  start_station_latitude  \
# 0               523          W 38 St & 8 Ave               40.754666
# 1               257  Lispenard St & Broadway               40.719392
# 2               479          9 Ave & W 45 St               40.760193
# 3               527          E 33 St & 1 Ave               40.743156
# 4               293    Lafayette St & E 8 St               40.730287
#
#    start_station_longitude  end_station_id  ... end_station_longitude  \
# 0               -73.991382             334  ...            -73.997262
# 1               -74.002472             236  ...            -73.987140
# 2               -73.991255             513  ...            -73.988639
# 3               -73.974347             441  ...            -73.967416
# 4               -73.990765             432  ...            -73.983799
#
#    trip_duration  subscriber  birth_year gender           ride_start  \
# 0            993  Subscriber      1968.0      2  2013-09-09 18:18:55
# 1            581  Subscriber      1983.0      1  2013-09-12 18:38:53
# 2            361  Subscriber      1989.0      1  2013-09-18 19:44:04
# 3            561  Subscriber      1988.0      2  2013-09-28 11:54:37
# 4            427  Subscriber      1986.0      2  2013-09-27 22:01:01
#
#               ride_end     Trip category ride_start_date ride_start_time
# 0  2013-09-09 18:35:28     10-20 minutes      2013-09-09        18:18:55
# 1  2013-09-12 18:48:34  under 10 minutes      2013-09-12        18:38:53
# 2  2013-09-18 19:50:05  under 10 minutes      2013-09-18        19:44:04
# 3  2013-09-28 12:03:58  under 10 minutes      2013-09-28        11:54:37
# 4  2013-09-27 22:08:08  under 10 minutes      2013-09-27        22:01:01
#
# [5 rows x 22 columns]

# %%
station_counts = citi.groupby('start_station_id')['ride_start_date'].count().reset_index()

# %%
#how many rides occured at that station
station_counts
# Out:
#      start_station_id  ride_start_date
# 0                  72              158
# 1                  79              122
# 2                  82               59
# 3                  83               72
# 4                 116              269
# ..                ...              ...
# 325              2017               90
# 326              2021              150
# 327              2022               96
# 328              2023               74
# 329              3002              203
#
# [330 rows x 2 columns]

# %%
#how many rides happened each day at each station
station_counts_day = citi.groupby(['start_station_id', 'day_of_week'])['ride_start_date'].count()

# %%
station_counts_day
# Out:
# start_station_id  day_of_week
# 72                Fri            31
#                   Mon            23
#                   Sat            23
#                   Sun            25
#                   Thu            21
#                                  ..
# 3002              Sat            37
#                   Sun            39
#                   Thu            20
#                   Tue            26
#                   Wed            31
# Name: ride_start_date, Length: 2276, dtype: int64

# %%
station_counts_day.head(20)
# Out:
# start_station_id  day_of_week
# 72                Fri            31
#                   Mon            23
#                   Sat            23
#                   Sun            25
#                   Thu            21
#                   Tue            16
#                   Wed            19
# 79                Fri            22
#                   Mon            15
#                   Sat            13
#                   Sun            11
#                   Thu            24
#                   Tue            16
#                   Wed            21
# 82                Fri             6
#                   Mon            12
#                   Sat             6
#                   Sun            11
#                   Thu             6
#                   Tue             8
# Name: ride_start_date, dtype: int64

# %%
station_counts.head(50)
# Out:
#     start_station_id  ride_start_date
# 0                 72              158
# 1                 79              122
# 2                 82               59
# 3                 83               72
# 4                116              269
# 5                119                7
# 6                120               25
# 7                127              253
# 8                128              264
# 9                137               76
# 10               143               48
# 11               144               13
# 12               146              113
# 13               147              235
# 14               150               89
# 15               151              294
# 16               152              129
# 17               153              186
# 18               157               68
# 19               160              117
# 20               161              199
# 21               164              123
# 22               167              180
# 23               168              257
# 24               173              157
# 25               174              117
# 26               195              158
# 27               212              144
# 28               216               36
# 29               217               51
# 30               218               25
# 31               223              186
# 32               224               98
# 33               225               89
# 34               228              126
# 35               229              154
# 36               232               30
# 37               233               94
# 38               236              172
# 39               237              205
# 40               238              121
# 41               239               53
# 42               241               40
# 43               242               22
# 44               243               88
# 45               244               39
# 46               245               19
# 47               247              121
# 48               248               36
# 49               249               79

# %%
station_counts.max()
# Out:
# start_station_id    3002
# ride_start_date      475
# dtype: int64

# %%
station_counts.min()
# Out:
# start_station_id    72
# ride_start_date      3
# dtype: int64

# %%
station_counts.mean()
# Out:
# start_station_id    447.809091
# ride_start_date     130.281818
# dtype: float64

# %%
#looking into station counts
sns.histplot(station_counts, bins=50, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
# select only needed columns
columns = ["day_of_week","start_hour","start_station_id","start_station_longitude","start_station_latitude","ride_start_date"]

# %%
citi_1 = citi[columns]

# %%
citi_1.head()
# Out:
#   day_of_week  start_hour  start_station_id  start_station_longitude  \
# 0         Mon          18               523               -73.991382
# 1         Thu          18               257               -74.002472
# 2         Wed          19               479               -73.991255
# 3         Sat          11               527               -73.974347
# 4         Fri          22               293               -73.990765
#
#    start_station_latitude ride_start_date
# 0               40.754666      2013-09-09
# 1               40.719392      2013-09-12
# 2               40.760193      2013-09-18
# 3               40.743156      2013-09-28
# 4               40.730287      2013-09-27

# %%
type(citi_1)
# Out:
# pandas.core.frame.DataFrame

# %%
citi_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42993 entries, 0 to 42992
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   day_of_week              42993 non-null  object
#  1   start_hour               42993 non-null  int64
#  2   start_station_id         42993 non-null  int64
#  3   start_station_longitude  42993 non-null  float64
#  4   start_station_latitude   42993 non-null  float64
#  5   ride_start_date          42993 non-null  object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.0+ MB

# %% [markdown]
# # Checking for Missing Values

# %%
citi_1.isnull().sum()
# Out:
# day_of_week                0
# start_hour                 0
# start_station_id           0
# start_station_longitude    0
# start_station_latitude     0
# ride_start_date            0
# dtype: int64

# %%
# Define data types for specific columns
data_types = {
    'ride_start_date': 'datetime64'
}

# %%
#converting to date time 
file_path = os.path.join(path, '02 Data','prepared data','citi_4.csv')

# %%
parse_dates = ['ride_start_date']

# %%
citi = pd.read_csv(file_path, parse_dates=parse_dates)

# %%
citi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42993 entries, 0 to 42992
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.2             42993 non-null  int64
#  1   Unnamed: 0.1             42993 non-null  int64
#  2   Unnamed: 0               42993 non-null  int64
#  3   day_of_week              42993 non-null  object
#  4   start_hour               42993 non-null  int64
#  5   start_station_id         42993 non-null  int64
#  6   start_station_name       42993 non-null  object
#  7   start_station_latitude   42993 non-null  float64
#  8   start_station_longitude  42993 non-null  float64
#  9   end_station_id           42993 non-null  int64
#  10  end_station_name         42993 non-null  object
#  11  end_station_latitude     42993 non-null  float64
#  12  end_station_longitude    42993 non-null  float64
#  13  trip_duration            42993 non-null  int64
#  14  subscriber               42993 non-null  object
#  15  birth_year               42993 non-null  float64
#  16  gender                   42993 non-null  int64
#  17  ride_start               42993 non-null  object
#  18  ride_end                 42993 non-null  object
#  19  Trip category            42993 non-null  object
#  20  ride_start_date          42993 non-null  datetime64[ns]
#  21  ride_start_time          42993 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(8), object(8)
# memory usage: 7.2+ MB

# %%
# Calculate rides per day for each station
station_daily_counts = citi.groupby(['start_station_id', citi['ride_start_date'].dt.date])['ride_start_date'].count()

# %%
#rides taken each day at each station
station_daily_counts
# Out:
# start_station_id  ride_start_date
# 72                2013-09-02          3
#                   2013-09-03          1
#                   2013-09-04          4
#                   2013-09-05          8
#                   2013-09-06         10
#                                      ..
# 3002              2013-09-26          9
#                   2013-09-27          7
#                   2013-09-28         12
#                   2013-09-29          6
#                   2013-09-30          3
# Name: ride_start_date, Length: 8667, dtype: int64

# %%
station_daily_counts.head(35)
# Out:
# start_station_id  ride_start_date
# 72                2013-09-02          3
#                   2013-09-03          1
#                   2013-09-04          4
#                   2013-09-05          8
#                   2013-09-06         10
#                   2013-09-07          6
#                   2013-09-08          7
#                   2013-09-09          5
#                   2013-09-10          7
#                   2013-09-11          7
#                   2013-09-12          7
#                   2013-09-13          7
#                   2013-09-14          7
#                   2013-09-15          8
#                   2013-09-16          4
#                   2013-09-17          4
#                   2013-09-19          1
#                   2013-09-20          6
#                   2013-09-21          5
#                   2013-09-22          5
#                   2013-09-23          6
#                   2013-09-24          4
#                   2013-09-25          8
#                   2013-09-26          5
#                   2013-09-27          8
#                   2013-09-28          5
#                   2013-09-29          5
#                   2013-09-30          5
# 79                2013-09-01          2
#                   2013-09-02          2
#                   2013-09-03          4
#                   2013-09-04          6
#                   2013-09-05          8
#                   2013-09-06          4
#                   2013-09-07          4
# Name: ride_start_date, dtype: int64

# %%
# average rides per day by start station
station_avg_rides_per_day = station_daily_counts.groupby('start_station_id').mean().reset_index()

# %%
#checking code
station_avg_rides_per_day
# Out:
#      start_station_id  ride_start_date
# 0                  72         5.642857
# 1                  79         4.357143
# 2                  82         2.185185
# 3                  83         2.571429
# 4                 116         8.966667
# ..                ...              ...
# 325              2017         3.000000
# 326              2021         5.357143
# 327              2022         3.310345
# 328              2023         3.217391
# 329              3002         6.766667
#
# [330 rows x 2 columns]

# %%
#changing column name
station_avg_rides_per_day= station_avg_rides_per_day.rename(columns={'ride_start_date':'average_daily_rides'})

# %%
#merging data sets
citi_1.head()
# Out:
#   day_of_week  start_hour  start_station_id  start_station_longitude  \
# 0         Mon          18               523               -73.991382
# 1         Thu          18               257               -74.002472
# 2         Wed          19               479               -73.991255
# 3         Sat          11               527               -73.974347
# 4         Fri          22               293               -73.990765
#
#    start_station_latitude ride_start_date
# 0               40.754666      2013-09-09
# 1               40.719392      2013-09-12
# 2               40.760193      2013-09-18
# 3               40.743156      2013-09-28
# 4               40.730287      2013-09-27

# %%
station_avg_rides_per_day.head()
# Out:
#    start_station_id  average_daily_rides
# 0                72             5.642857
# 1                79             4.357143
# 2                82             2.185185
# 3                83             2.571429
# 4               116             8.966667

# %%
station_avg_rides_per_day.shape
# Out:
# (330, 2)

# %%
nyc_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# %%
# lat and long for each station
station_loc = citi.groupby('start_station_id')[['start_station_latitude', 'start_station_longitude']].mean()

# %%
station_loc
# Out:
#                   start_station_latitude  start_station_longitude
# start_station_id
# 72                             40.767272               -73.993929
# 79                             40.719116               -74.006667
# 82                             40.711174               -74.000165
# 83                             40.683826               -73.976323
# 116                            40.741776               -74.001497
# ...                                  ...                      ...
# 2017                           40.750224               -73.971214
# 2021                           40.759291               -73.988597
# 2022                           40.758491               -73.959206
# 2023                           40.759681               -73.970314
# 3002                           40.711512               -74.015756
#
# [330 rows x 2 columns]

# %%
# each station with lat and longitude and avg daily rides
df_merged = station_loc.merge(station_avg_rides_per_day, on = 'start_station_id')

# %%
df_merged
# Out:
#      start_station_id  start_station_latitude  start_station_longitude  \
# 0                  72               40.767272               -73.993929
# 1                  79               40.719116               -74.006667
# 2                  82               40.711174               -74.000165
# 3                  83               40.683826               -73.976323
# 4                 116               40.741776               -74.001497
# ..                ...                     ...                      ...
# 325              2017               40.750224               -73.971214
# 326              2021               40.759291               -73.988597
# 327              2022               40.758491               -73.959206
# 328              2023               40.759681               -73.970314
# 329              3002               40.711512               -74.015756
#
#      average_daily_rides
# 0               5.642857
# 1               4.357143
# 2               2.185185
# 3               2.571429
# 4               8.966667
# ..                   ...
# 325             3.000000
# 326             5.357143
# 327             3.310345
# 328             3.217391
# 329             6.766667
#
# [330 rows x 4 columns]

# %%
data_to_plot = df_merged[['start_station_id','average_daily_rides',]]
data_to_plot.head()
# Out:
#    start_station_id  average_daily_rides
# 0                72             5.642857
# 1                79             4.357143
# 2                82             2.185185
# 3                83             2.571429
# 4               116             8.966667

# %%
data_to_plot_1 = df_merged[['start_station_longitude','start_station_latitude','average_daily_rides',]]
data_to_plot_1.head()
# Out:
#    start_station_longitude  start_station_latitude  average_daily_rides
# 0               -73.993929               40.767272             5.642857
# 1               -74.006667               40.719116             4.357143
# 2               -74.000165               40.711174             2.185185
# 3               -73.976323               40.683826             2.571429
# 4               -74.001497               40.741776             8.966667

# %%
df_merged['average_daily_rides'].max()
# Out:
# 15.833333333333334

# %%
df_merged['average_daily_rides'].mean()
# Out:
# 4.609605418741775

# %%
# Avg Daily Rides Bins
sns.histplot(df_merged['average_daily_rides'], bins=15, kde = True)
# Out:
# <Axes: xlabel='average_daily_rides', ylabel='Count'>

# %%
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74fdd29c962fef02cbc548118b03b41e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74fdd29c962fef02cbc548118b03b41e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74fdd29c962fef02cbc548118b03b41e = L.map(
#                 &quot;map_74fdd29c962fef02cbc548118b03b41e&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f58232e062a46591816c57921591b2f7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74fdd29c962fef02cbc548118b03b41e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import geopandas as gpd
from shapely.geometry import Point

# %%
start_station_id.forEach(station => {
  var marker = new mapboxgl.Marker()
    .setLngLat([station.longitude, station.latitude])
    .addTo(nyc_map);
});
# Out:
#   Cell In[124], line 1
#     start_station_id.forEach(station => {
#                                       ^
# SyntaxError: invalid syntax

# %%
data_to_plot_1.head()
# Out:
#    start_station_longitude  start_station_latitude  average_daily_rides
# 0               -73.993929               40.767272             5.642857
# 1               -74.006667               40.719116             4.357143
# 2               -74.000165               40.711174             2.185185
# 3               -73.976323               40.683826             2.571429
# 4               -74.001497               40.741776             8.966667

# %%
data_to_plot_2= df_merged[['start_station_longitude','start_station_latitude']]

# %%
data_to_plot_2.head()
# Out:
#    start_station_longitude  start_station_latitude
# 0               -73.993929               40.767272
# 1               -74.006667               40.719116
# 2               -74.000165               40.711174
# 3               -73.976323               40.683826
# 4               -74.001497               40.741776

# %%
# trying to get a NYC map imported and the lat and long of the zip codes
import folium
from folium.plugins import MarkerCluster

# %%
map_zip = folium.Map(location=[40.693943, -73.985880], default_zoom_start=12)

# %%
choropleth_layer = folium.Choropleth(
    geo_data=city_geo_2,
    name="Choropleth Map"
).add_to(map_zip)

# %%
folium.LayerControl().add_to(map_zip)

# %%
map_zip
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f51f818a51265b7ade909331c01e6dfa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f51f818a51265b7ade909331c01e6dfa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f51f818a51265b7ade909331c01e6dfa = L.map(
#                 &quot;map_f51f818a51265b7ade909331c01e6dfa&quot;,
#                 {
#                     center: [40.693943, -73.98588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     defaultZoomStart: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11f4b54efd5ca1c2045e2a095c617170 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f51f818a51265b7ade909331c01e6dfa);
#
#
#             var choropleth_415aec448aeb4e90f6d9919c1274a482 = L.featureGroup(
#                 {}
#             ).addTo(map_f51f818a51265b7ade909331c01e6dfa);
#
#
#         function geo_json_89d38bd019d0c5980c4c26497e3bbe46_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_89d38bd019d0c5980c4c26497e3bbe46_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_89d38bd019d0c5980c4c26497e3bbe46 = L.geoJson(null, {
#                 onEachFeature: geo_json_89d38bd019d0c5980c4c26497e3bbe46_onEachFeature,
#
#                 style: geo_json_89d38bd019d0c5980c4c26497e3bbe46_styler,
#         });
#
#         function geo_json_89d38bd019d0c5980c4c26497e3bbe46_add (data) {
#             geo_json_89d38bd019d0c5980c4c26497e3bbe46
#                 .addData(data)
#                 .addTo(choropleth_415aec448aeb4e90f6d9919c1274a482);
#         }
#             geo_json_89d38bd019d0c5980c4c26497e3bbe46_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-73.86942457284175, 40.74915687096787], [-73.89507143240856, 40.74646547081214], [-73.89618737867819, 40.74850942518086], [-73.89583954185139, 40.748546875706005], [-73.89525242774396, 40.74830660945023], [-73.89654041085561, 40.750541998143575], [-73.89579868613828, 40.750619721332605], [-73.89652230661433, 40.75438879610902], [-73.87221855882477, 40.756943248067465], [-73.87167992356791, 40.75398717439602], [-73.87207046513889, 40.75386200705204], [-73.86942457284175, 40.74915687096787]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: 0, &quot;properties&quot;: {&quot;@id&quot;: &quot;http://nyc.pediacities.com/Resource/PostalCode/11372&quot;, &quot;BLDGpostalCode&quot;: 0, &quot;CTY_FIPS&quot;: &quot;081&quot;, &quot;OBJECTID&quot;: 1, &quot;PO_NAME&quot;: &quot;Jackson Heights&quot;, &quot;STATE&quot;: &quot;NY&quot;, &quot;ST_FIPS&quot;: &quot;36&quot;, &quot;Shape_Area&quot;: 20163283.8744, &quot;Shape_Leng&quot;: 20624.6923165, &quot;borough&quot;: &quot;Queens&quot;, &quot;postalCode&quot;: &quot;11372&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-73.71068374074007, 40.75004039450917], [-73.70869392379947, 40.74875836557175], [-73.70713084684175, 40.749582740537946], [-73.70419967936361, 40.75016955256976], [-73.7021852869823, 40.74474188775384], [-73.70308721830735, 40.74454725735512], [-73.70098278625547, 40.73889569923034], [-73.71371033246908, 40.736174704865455], [-73.71567895968894, 40.73962914915626], [-73.71867075939582, 40.74631499057428], [-73.71966142935703, 40.748945236431474], [-73.72082889049311, 40.751173028173014], [-73.72117809110456, 40.75232189224561], [-73.72250622247415, 40.753358470814895], [-73.72270447144122, 40.75373371438336], [-73.72183610276068, 40.75486513130315], [-73.72109289651769, 40.7562813418113], [-73.71775341502477, 40.75534755942338], [-73.71730957335735, 40.75595782995615], [-73.71534601002345, 40.75550893330126], [-73.71553103019596, 40.75506458072391], [-73.71541781535772, 40.7549984440815], [-73.71509806179287, 40.75181177075926], [-73.71132911125308, 40.74947450816085], [-73.71068374074007, 40.75004039450917]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: 1, &quot;properties&quot;: {&quot;@id&quot;: &quot;http://nyc.pediacities.com/Resource/PostalCode/11004&quot;, &quot;BLDGpostalCode&quot;: 0, &quot;CTY_FIPS&quot;: &quot;081&quot;, &quot;OBJECTID&quot;: 2, &quot;PO_NAME&quot;: &quot;Glen Oaks&quot;, &quot;STATE&quot;: &quot;NY&quot;, &quot;ST_FIPS&quot;: &quot;36&quot;, &quot;Shape_Area&quot;: 22606526.9139, &quot;Shape_Leng&quot;: 23002.8160385, &quot;borough&quot;: &quot;Queens&quot;, &quot;postalCode&quot;: &quot;11004&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geo

# %%
df_merged
# Out:
#      start_station_id  start_station_latitude  start_station_longitude  \
# 0                  72               40.767272               -73.993929
# 1                  79               40.719116               -74.006667
# 2                  82               40.711174               -74.000165
# 3                  83               40.683826               -73.976323
# 4                 116               40.741776               -74.001497
# ..                ...                     ...                      ...
# 325              2017               40.750224               -73.971214
# 326              2021               40.759291               -73.988597
# 327              2022               40.758491               -73.959206
# 328              2023               40.759681               -73.970314
# 329              3002               40.711512               -74.015756
#
#      average_daily_rides
# 0               5.642857
# 1               4.357143
# 2               2.185185
# 3               2.571429
# 4               8.966667
# ..                   ...
# 325             3.000000
# 326             5.357143
# 327             3.310345
# 328             3.217391
# 329             6.766667
#
# [330 rows x 4 columns]

# %%
df_merged.to_csv(os.path.join(path, '02 Data','prepared data', 'bike_station.csv'))

# %%
# Loop through bike stations
for index, row in df_merged.iterrows():
    folium.Marker(
        location=[row["start_station_latitude"], row["start_station_longitude"]],
        popup=row["start_station_id"],
        icon=folium.Icon(color="lightgreen", icon="bicycle")
    ).add_to(map_zip)

# %%
# Add a layer control
folium.LayerControl().add_to(map_zip)

# %%
map_zip
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f51f818a51265b7ade909331c01e6dfa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f51f818a51265b7ade909331c01e6dfa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f51f818a51265b7ade909331c01e6dfa = L.map(
#                 &quot;map_f51f818a51265b7ade909331c01e6dfa&quot;,
#                 {
#                     center: [40.693943, -73.98588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     defaultZoomStart: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11f4b54efd5ca1c2045e2a095c617170 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f51f818a51265b7ade909331c01e6dfa);
#
#
#             var choropleth_415aec448aeb4e90f6d9919c1274a482 = L.featureGroup(
#                 {}
#             ).addTo(map_f51f818a51265b7ade909331c01e6dfa);
#
#
#         function geo_json_89d38bd019d0c5980c4c26497e3bbe46_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_89d38bd019d0c5980c4c26497e3bbe46_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_89d38bd019d0c5980c4c26497e3bbe46 = L.geoJson(null, {
#                 onEachFeature: geo_json_89d38bd019d0c5980c4c26497e3bbe46_onEachFeature,
#
#                 style: geo_json_89d38bd019d0c5980c4c26497e3bbe46_styler,
#         });
#
#         function geo_json_89d38bd019d0c5980c4c26497e3bbe46_add (data) {
#             geo_json_89d38bd019d0c5980c4c26497e3bbe46
#                 .addData(data)
#                 .addTo(choropleth_415aec448aeb4e90f6d9919c1274a482);
#         }
#             geo_json_89d38bd019d0c5980c4c26497e3bbe46_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-73.86942457284175, 40.74915687096787], [-73.89507143240856, 40.74646547081214], [-73.89618737867819, 40.74850942518086], [-73.89583954185139, 40.748546875706005], [-73.89525242774396, 40.74830660945023], [-73.89654041085561, 40.750541998143575], [-73.89579868613828, 40.750619721332605], [-73.89652230661433, 40.75438879610902], [-73.87221855882477, 40.756943248067465], [-73.87167992356791, 40.75398717439602], [-73.87207046513889, 40.75386200705204], [-73.86942457284175, 40.74915687096787]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: 0, &quot;properties&quot;: {&quot;@id&quot;: &quot;http://nyc.pediacities.com/Resource/PostalCode/11372&quot;, &quot;BLDGpostalCode&quot;: 0, &quot;CTY_FIPS&quot;: &quot;081&quot;, &quot;OBJECTID&quot;: 1, &quot;PO_NAME&quot;: &quot;Jackson Heights&quot;, &quot;STATE&quot;: &quot;NY&quot;, &quot;ST_FIPS&quot;: &quot;36&quot;, &quot;Shape_Area&quot;: 20163283.8744, &quot;Shape_Leng&quot;: 20624.6923165, &quot;borough&quot;: &quot;Queens&quot;, &quot;postalCode&quot;: &quot;11372&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-73.71068374074007, 40.75004039450917], [-73.70869392379947, 40.74875836557175], [-73.70713084684175, 40.749582740537946], [-73.70419967936361, 40.75016955256976], [-73.7021852869823, 40.74474188775384], [-73.70308721830735, 40.74454725735512], [-73.70098278625547, 40.73889569923034], [-73.71371033246908, 40.736174704865455], [-73.71567895968894, 40.73962914915626], [-73.71867075939582, 40.74631499057428], [-73.71966142935703, 40.748945236431474], [-73.72082889049311, 40.751173028173014], [-73.72117809110456, 40.75232189224561], [-73.72250622247415, 40.753358470814895], [-73.72270447144122, 40.75373371438336], [-73.72183610276068, 40.75486513130315], [-73.72109289651769, 40.7562813418113], [-73.71775341502477, 40.75534755942338], [-73.71730957335735, 40.75595782995615], [-73.71534601002345, 40.75550893330126], [-73.71553103019596, 40.75506458072391], [-73.71541781535772, 40.7549984440815], [-73.71509806179287, 40.75181177075926], [-73.71132911125308, 40.74947450816085], [-73.71068374074007, 40.75004039450917]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: 1, &quot;properties&quot;: {&quot;@id&quot;: &quot;http://nyc.pediacities.com/Resource/PostalCode/11004&quot;, &quot;BLDGpostalCode&quot;: 0, &quot;CTY_FIPS&quot;: &quot;081&quot;, &quot;OBJECTID&quot;: 2, &quot;PO_NAME&quot;: &quot;Glen Oaks&quot;, &quot;STATE&quot;: &quot;NY&quot;, &quot;ST_FIPS&quot;: &quot;36&quot;, &quot;Shape_Area&quot;: 22606526.9139, &quot;Shape_Leng&quot;: 23002.8160385, &quot;borough&quot;: &quot;Queens&quot;, &quot;postalCode&quot;: &quot;11004&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geo

# %%
import folium
import geopandas as gpd
from shapely.geometry import Point

# %%
area_geojson = r'/Users/simpe/Achievement 6 practice/Data/nyc-zip-code-tabulation-areas-polygons.geojson'

# %%
geojson_gdf = gpd.read_file(area_geojson)

# %%
# Convert bike station DataFrame to GeoDataFrame
geometry = [Point(xy) for xy in zip(df_merged["start_station_longitude"], df_merged["start_station_latitude"])]
bike_stations_gdf = gpd.GeoDataFrame(df_merged, geometry=geometry, crs=geojson_gdf.crs)

# %%
merged_gdf = gpd.sjoin(bike_stations_gdf, geojson_gdf, predicate="within")

# %%
merged_gdf
# Out:
#      start_station_id  start_station_latitude  start_station_longitude  \
# 0                  72               40.767272               -73.993929
# 1                  79               40.719116               -74.006667
# 2                  82               40.711174               -74.000165
# 3                  83               40.683826               -73.976323
# 4                 116               40.741776               -74.001497
# ..                ...                     ...                      ...
# 325              2017               40.750224               -73.971214
# 326              2021               40.759291               -73.988597
# 327              2022               40.758491               -73.959206
# 328              2023               40.759681               -73.970314
# 329              3002               40.711512               -74.015756
#
#      average_daily_rides                    geometry  index_right  OBJECTID  \
# 0               5.642857  POINT (-73.99393 40.76727)          203       204
# 1               4.357143  POINT (-74.00667 40.71912)          127       128
# 2               2.185185  POINT (-74.00017 40.71117)          132       133
# 3               2.571429  POINT (-73.97632 40.68383)          148       149
# 4               8.966667  POINT (-74.00150 40.74178)          114       115
# ..                   ...                         ...          ...       ...
# 325             3.000000  POINT (-73.97121 40.75022)          112       113
# 326             5.357143  POINT (-73.98860 40.75929)          105       106
# 327             3.310345  POINT (-73.95921 40.75849)          238       239
# 328             3.217391  POINT (-73.97031 40.75968)          238       239
# 329             6.766667  POINT (-74.01576 40.71151)          260       261
#
#     postalCode   PO_NAME STATE    borough ST_FIPS CTY_FIPS  BLDGpostalCode  \
# 0        10019  New York    NY  Manhattan      36      061               0
# 1        10013  New York    NY  Manhattan      36      061               0
# 2        10038  New York    NY  Manhattan      36      061               0
# 3        11217  Brooklyn    NY   Brooklyn      36      047               0
# 4        10011  New York    NY  Manhattan      36      061               0
# ..         ...       ...   ...        ...     ...      ...             ...
# 325      10017  New York    NY  Manhattan      36      061               0
# 326      10036  New York    NY  Manhattan      36      061               0
# 327      10022  New York    NY  Manhattan      36      061               0
# 328      10022  New York    NY  Manhattan      36      061               0
# 329      10281  New York    NY  Manhattan      36      061               0
#
#        Shape_Leng    Shape_Area  \
# 0    24983.441628  1.882838e+07
# 1    19248.015538  1.558058e+07
# 2    12605.262428  7.022761e+06
# 3    22010.965366  2.164816e+07
# 4    24714.121442  1.811842e+07
# ..            ...           ...
# 325  14308.645626  9.794383e+06
# 326  16418.606668  1.139511e+07
# 327  14672.453150  1.272834e+07
# 328  14672.453150  1.272834e+07
# 329   4717.025266  9.580872e+05
#
#                                                    @id
# 0    http://nyc.pediacities.com/Resource/PostalCode...
# 1    http://nyc.pediacities.com/Resource/PostalCode...
# 2    http://nyc.pediacities.com/Resource/PostalCode...
# 3    http://nyc.pediacities.com/Resource/PostalCode...
# 4    http://nyc.pediacities.com/Resource/PostalCode...
# ..                                                 ...
# 325  http://nyc.pediacities.com/Resource/PostalCode...
# 326  http://nyc.pediacities.com/Resource/PostalCode...
# 327  http://nyc.pediacities.com/Resource/PostalCode...
# 328  http://nyc.pediacities.com/Resource/PostalCode...
# 329  http://nyc.pediacities.com/Resource/PostalCode...
#
# [330 rows x 17 columns]

# %%
merged_gdf_1=merged_gdf.drop(columns=["geometry","index_right","OBJECTID","PO_NAME","STATE","borough","ST_FIPS","CTY_FIPS","BLDGpostalCode","Shape_Leng","Shape_Area","@id"])

# %%
merged_gdf_1
# Out:
#      start_station_id  start_station_latitude  start_station_longitude  \
# 0                  72               40.767272               -73.993929
# 1                  79               40.719116               -74.006667
# 2                  82               40.711174               -74.000165
# 3                  83               40.683826               -73.976323
# 4                 116               40.741776               -74.001497
# ..                ...                     ...                      ...
# 325              2017               40.750224               -73.971214
# 326              2021               40.759291               -73.988597
# 327              2022               40.758491               -73.959206
# 328              2023               40.759681               -73.970314
# 329              3002               40.711512               -74.015756
#
#      average_daily_rides postalCode
# 0               5.642857      10019
# 1               4.357143      10013
# 2               2.185185      10038
# 3               2.571429      11217
# 4               8.966667      10011
# ..                   ...        ...
# 325             3.000000      10017
# 326             5.357143      10036
# 327             3.310345      10022
# 328             3.217391      10022
# 329             6.766667      10281
#
# [330 rows x 5 columns]

# %%
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74fdd29c962fef02cbc548118b03b41e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74fdd29c962fef02cbc548118b03b41e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74fdd29c962fef02cbc548118b03b41e = L.map(
#                 &quot;map_74fdd29c962fef02cbc548118b03b41e&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f58232e062a46591816c57921591b2f7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74fdd29c962fef02cbc548118b03b41e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
choropleth_layer = folium.Choropleth(
    geo_data=area_geojson,
    data=merged_gdf_1,
    columns=["postalCode", "average_daily_rides"],
    key_on="feature.properties.postalCode",  
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Average Daily Use"
).add_to(nyc_map)

# %%
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74fdd29c962fef02cbc548118b03b41e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74fdd29c962fef02cbc548118b03b41e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74fdd29c962fef02cbc548118b03b41e = L.map(
#                 &quot;map_74fdd29c962fef02cbc548118b03b41e&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f58232e062a46591816c57921591b2f7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74fdd29c962fef02cbc548118b03b41e);
#
#
#             var choropleth_43527034c74583048298b9919dff76fd = L.featureGroup(
#                 {}
#             ).addTo(map_74fdd29c962fef02cbc548118b03b41e);
#
#
#         function geo_json_2eaa64fc21283f95cd919c1d0ac539da_styler(feature) {
#             switch(feature.id) {
#                 case 25: case 113: case 132: case 137: case 138: case 141: case 142: case 145: case 146: case 149:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 82: case 109: case 203:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 89: case 129: case 261:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 105: case 118: case 120: case 123: case 125:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 110: case 112: case 115: case 121: case 127: case 128: case 136: case 140: case 148: case 193: case 238:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 114: case 126: case 260:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2eaa64fc21283f95cd919c1d0ac539da_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2eaa64fc21283f95cd919c1d0ac539da = L.geoJson(null, {
#                 onEachFeature: geo_json_2eaa64fc21283f95cd919c1d0ac539da_onEachFeature,
#
#                 style: geo_json_2eaa64fc21283f95cd919c1d0ac539da_styler,
#         });
#
#         function geo_json_2eaa64fc21283f95cd919c1d0ac539da_add (data) {
#             geo_json_2eaa64fc21283f95cd919c1d0ac539da
#                 .addData(data)
#                 .addTo(choropleth_43527034c74583048298b9919dff76fd);
#         }
#             geo_json_2eaa64fc21283f95cd919c1d0ac539da_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-73.86942457284175, 40.74915687096787], [-73.89507143240856, 40.74646547081214], [-73.89618737867819, 40.74850942518086], [-73.89583954185139, 40.748546875706005], [-73.89525242774396, 40.74830660945023], [-73.89654041085561, 40.750541998143575], [-73.89579868613828, 40.750619721332605], [-73.89652230661433, 40.75438879610902], [-73.87221855882477, 40.756943248067465], [-73.87167992356791, 40.75398717439602], [-73.87207046513889, 40.75386200705204], [-73.86942457284175, 40.74915687096787]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: 0, &quot;properties&quot;: {&quot;@id&quot;: &quot;http://nyc.pediacities.com/Resource/PostalCode/11372&quot;, &quot;BLDGpostalCode&quot;: 0, &quot;CTY_FIPS&quot;: &quot;081&quot;, &quot;OBJECTID&quot;: 1, &quot;PO_NAME&quot;: &quot;Jackson Heights&quot;, &quot;STATE&quot;: &quot;NY&quot;, &quot;ST_FIPS&quot;: &quot;36&quot;, &quot;Shape_Area&quot;: 20163283.8744, &quot;Shape_Leng&quot;: 20624.6923165, &quot;borough&quot;: &quot;Queens&quot;, &quot;postalCode&quot;: &quot;11372&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&q

# %%
# Loop through bike stations
for index, row in df_merged.iterrows():
    folium.Marker(
        location=[row["start_station_latitude"], row["start_station_longitude"]],
        popup=row["start_station_id"],
        icon=folium.Icon(color="blue", icon="bicycle")
    ).add_to(nyc_map)

# %%
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74fdd29c962fef02cbc548118b03b41e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74fdd29c962fef02cbc548118b03b41e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74fdd29c962fef02cbc548118b03b41e = L.map(
#                 &quot;map_74fdd29c962fef02cbc548118b03b41e&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f58232e062a46591816c57921591b2f7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74fdd29c962fef02cbc548118b03b41e);
#
#
#             var choropleth_43527034c74583048298b9919dff76fd = L.featureGroup(
#                 {}
#             ).addTo(map_74fdd29c962fef02cbc548118b03b41e);
#
#
#         function geo_json_2eaa64fc21283f95cd919c1d0ac539da_styler(feature) {
#             switch(feature.id) {
#                 case 25: case 113: case 132: case 137: case 138: case 141: case 142: case 145: case 146: case 149:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 82: case 109: case 203:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 89: case 129: case 261:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 105: case 118: case 120: case 123: case 125:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 110: case 112: case 115: case 121: case 127: case 128: case 136: case 140: case 148: case 193: case 238:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 114: case 126: case 260:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2eaa64fc21283f95cd919c1d0ac539da_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2eaa64fc21283f95cd919c1d0ac539da = L.geoJson(null, {
#                 onEachFeature: geo_json_2eaa64fc21283f95cd919c1d0ac539da_onEachFeature,
#
#                 style: geo_json_2eaa64fc21283f95cd919c1d0ac539da_styler,
#         });
#
#         function geo_json_2eaa64fc21283f95cd919c1d0ac539da_add (data) {
#             geo_json_2eaa64fc21283f95cd919c1d0ac539da
#                 .addData(data)
#                 .addTo(choropleth_43527034c74583048298b9919dff76fd);
#         }
#             geo_json_2eaa64fc21283f95cd919c1d0ac539da_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-73.86942457284175, 40.74915687096787], [-73.89507143240856, 40.74646547081214], [-73.89618737867819, 40.74850942518086], [-73.89583954185139, 40.748546875706005], [-73.89525242774396, 40.74830660945023], [-73.89654041085561, 40.750541998143575], [-73.89579868613828, 40.750619721332605], [-73.89652230661433, 40.75438879610902], [-73.87221855882477, 40.756943248067465], [-73.87167992356791, 40.75398717439602], [-73.87207046513889, 40.75386200705204], [-73.86942457284175, 40.74915687096787]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: 0, &quot;properties&quot;: {&quot;@id&quot;: &quot;http://nyc.pediacities.com/Resource/PostalCode/11372&quot;, &quot;BLDGpostalCode&quot;: 0, &quot;CTY_FIPS&quot;: &quot;081&quot;, &quot;OBJECTID&quot;: 1, &quot;PO_NAME&quot;: &quot;Jackson Heights&quot;, &quot;STATE&quot;: &quot;NY&quot;, &quot;ST_FIPS&quot;: &quot;36&quot;, &quot;Shape_Area&quot;: 20163283.8744, &quot;Shape_Leng&quot;: 20624.6923165, &quot;borough&quot;: &quot;Queens&quot;, &quot;postalCode&quot;: &quot;11372&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&q

# %%
nyc_map.save('plot_data.html')

# %%
citi.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 day_of_week  start_hour  \
# 0             0             0           0         Mon          18
# 1             1             1           1         Thu          18
# 2             2             2           2         Wed          19
# 3             3             3           3         Sat          11
# 4             4             4           4         Fri          22
#
#    start_station_id       start_station_name  start_station_latitude  \
# 0               523          W 38 St & 8 Ave               40.754666
# 1               257  Lispenard St & Broadway               40.719392
# 2               479          9 Ave & W 45 St               40.760193
# 3               527          E 33 St & 1 Ave               40.743156
# 4               293    Lafayette St & E 8 St               40.730287
#
#    start_station_longitude  end_station_id  ... end_station_longitude  \
# 0               -73.991382             334  ...            -73.997262
# 1               -74.002472             236  ...            -73.987140
# 2               -73.991255             513  ...            -73.988639
# 3               -73.974347             441  ...            -73.967416
# 4               -73.990765             432  ...            -73.983799
#
#    trip_duration  subscriber  birth_year gender           ride_start  \
# 0            993  Subscriber      1968.0      2  2013-09-09 18:18:55
# 1            581  Subscriber      1983.0      1  2013-09-12 18:38:53
# 2            361  Subscriber      1989.0      1  2013-09-18 19:44:04
# 3            561  Subscriber      1988.0      2  2013-09-28 11:54:37
# 4            427  Subscriber      1986.0      2  2013-09-27 22:01:01
#
#               ride_end     Trip category ride_start_date ride_start_time
# 0  2013-09-09 18:35:28     10-20 minutes      2013-09-09        18:18:55
# 1  2013-09-12 18:48:34  under 10 minutes      2013-09-12        18:38:53
# 2  2013-09-18 19:50:05  under 10 minutes      2013-09-18        19:44:04
# 3  2013-09-28 12:03:58  under 10 minutes      2013-09-28        11:54:37
# 4  2013-09-27 22:08:08  under 10 minutes      2013-09-27        22:01:01
#
# [5 rows x 22 columns]

# %%
citi.to_csv(os.path.join(path, '02 Data','prepared data', 'citi_5.csv'))

# %%
merged_gdf_1.head()
# Out:
#    start_station_id  start_station_latitude  start_station_longitude  \
# 0                72               40.767272               -73.993929
# 1                79               40.719116               -74.006667
# 2                82               40.711174               -74.000165
# 3                83               40.683826               -73.976323
# 4               116               40.741776               -74.001497
#
#    average_daily_rides postalCode
# 0             5.642857      10019
# 1             4.357143      10013
# 2             2.185185      10038
# 3             2.571429      11217
# 4             8.966667      10011

# %%
merged_gdf_1.to_csv(os.path.join(path, '02 Data','prepared data', 'postalcodes'))
